# %% [markdown]
# 6개의 subplot 을 만들고 각각에 다른 차트 그려보기

# %%
# %matplotlib nbagg

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax1 = fig.add_subplot(2,3,1)
ax2 = fig.add_subplot(2,3,2)
ax3 = fig.add_subplot(2,3,3)
ax4 = fig.add_subplot(2,3,4)
ax5 = fig.add_subplot(2,3,5)
ax6 = fig.add_subplot(2,3,6)

# %%
list1 = pd.Series(np.random.randn(10).cumsum(), index=list('abcdefghij'))

# %%
ax4.plot(list, kind = "barh", ax = ax4[0])
# Out:
#   File "<ipython-input-41-f8b8f70ab8b9>", line 1
#     ax4.plot(list, kind = "barh", ax4[0])
#                                  ^
# SyntaxError: positional argument follows keyword argument
