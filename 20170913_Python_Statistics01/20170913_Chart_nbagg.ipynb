# %%
# %matplotlib nbagg

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax3 = fig.add_subplot(2,2,4)

# %%
plt.plot(np.random.rand(50).cumsum())
#마지막 차트에 값이 들어가게 된다.

# %%
ax1.hist(np.random.rand(100),bins=20)
# Out:
# (array([ 7.,  2.,  5.,  4.,  3.,  4.,  8.,  8.,  3.,  6.,  9.,  6.,  4.,
#          4.,  3.,  4.,  5.,  4.,  7.,  4.]),
#  array([ 0.01056674,  0.05785945,  0.10515216,  0.15244487,  0.19973758,
#          0.24703029,  0.294323  ,  0.34161571,  0.38890842,  0.43620113,
#          0.48349384,  0.53078655,  0.57807926,  0.62537197,  0.67266468,
#          0.71995739,  0.7672501 ,  0.81454281,  0.86183552,  0.90912824,
#          0.95642095]),
#  <a list of 20 Patch objects>)

# %%
ax2.scatter(np.arange(30),np.arange(30)+3*np.random.rand(30))

# %%
axes = plt.subplots(2,3)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(np.random.rand(16),color="g",marker="p",linestyle="--")

# %%
plt.plot(np.random.rand(16),"g.-")
#Color, Marker, Linestyle 을 간단히 위와 같이 표시할 수 있다.

# %%
fig, axes2 = plt.subplots(2,1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data2 = pd.Series(np.random.rand(16), index = list('abcdefghijklmnop'))
data2
# Out:
# a    0.302320
# b    0.147501
# c    0.580912
# d    0.809804
# e    0.378024
# f    0.164548
# g    0.571870
# h    0.604364
# i    0.738874
# j    0.467572
# k    0.749391
# l    0.916650
# m    0.076202
# n    0.982791
# o    0.406521
# p    0.382440
# dtype: float64

# %%
data2.plot(kind="bar", ax = axes2[0], color = 'g', alpha = 0.7) #axes : 빈 좌표 평면을 나타내는 변수

# %%
data2.plot(kind="barh", ax = axes2[1], color = 'g', alpha = 0.3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d4a44206413d> in <module>()
# ----> 1 data2.plot(kind="barh", ax = axes2[1], color = 'g', alpha = 0.3)
#
# NameError: name 'data2' is not defined
