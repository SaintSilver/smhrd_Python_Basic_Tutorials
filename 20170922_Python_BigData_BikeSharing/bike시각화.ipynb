# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Load Dataset

# %%
train = pd.read_csv("biketrain.csv",parse_dates=["datetime"])
train.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
train["datatime-year"]=train["datetime"].dt.year
train["datatime-month"]=train["datetime"].dt.month
train["datatime-day"]=train["datetime"].dt.day
train["datatime-hour"]=train["datetime"].dt.hour
train["datatime-minute"]=train["datetime"].dt.minute
train["datatime-second"]=train["datetime"].dt.second

train[["datetime","datatime-year","datatime-month","datatime-day","datatime-hour","datatime-minute","datatime-second"]]
# Out:
#                  datetime  datatime-year  datatime-month  datatime-day  \
# 0     2011-01-01 00:00:00           2011               1             1
# 1     2011-01-01 01:00:00           2011               1             1
# 2     2011-01-01 02:00:00           2011               1             1
# 3     2011-01-01 03:00:00           2011               1             1
# 4     2011-01-01 04:00:00           2011               1             1
# 5     2011-01-01 05:00:00           2011               1             1
# 6     2011-01-01 06:00:00           2011               1             1
# 7     2011-01-01 07:00:00           2011               1             1
# 8     2011-01-01 08:00:00           2011               1             1
# 9     2011-01-01 09:00:00           2011               1             1
# 10    2011-01-01 10:00:00           2011               1             1
# 11    2011-01-01 11:00:00           2011               1             1
# ...

# %%
sns.barplot(data=train, x="datatime-day", y="count")

# %%
sns.barplot(data=train, x="datatime-month", y="count")

# %%
sns.barplot(data=train, x="datatime-hour", y="count")

# %%
#date min과 second는 사용되지않으니 필요없다 , day가 19일까지밖에없다..차이도없고 , 

figure,((ax1,ax2,ax3),(ax4,ax5,ax6)) = plt.subplots(nrows=2, ncols=3)
figure.set_size_inches(18,8)

sns.barplot(data=train, x="datatime-year", y="count", ax=ax1)
sns.barplot(data=train, x="datatime-month", y="count", ax=ax2)
sns.barplot(data=train, x="datatime-day", y="count", ax=ax3)
sns.barplot(data=train, x="datatime-hour", y="count", ax=ax4)
sns.barplot(data=train, x="datatime-minute", y="count", ax=ax5)
sns.barplot(data=train, x="datatime-second", y="count", ax=ax6)

# %%
# hue = 기준점

#주중에는 출근 퇴근시간, 주말엔 오후에 대여를 많이하고있단걸 볼수있다.

figure, (ax1,ax2) = plt.subplots(nrows=2, ncols=1)
figure.set_size_inches(18,8)

sns.pointplot(data=train, x="datatime-hour",y="count",ax=ax1)
sns.pointplot(data=train, x="datatime-hour",y="count",hue="workingday",ax=ax2)

# %%
train["datatime-dayofweek"]=train["datetime"].dt.dayofweek
train[["datetime","datatime-dayofweek"]].head()
# Out:
#              datetime  datatime-dayofweek
# 0 2011-01-01 00:00:00                   5
# 1 2011-01-01 01:00:00                   5
# 2 2011-01-01 02:00:00                   5
# 3 2011-01-01 03:00:00                   5
# 4 2011-01-01 04:00:00                   5

# %%
# hue = 기준점

#주중에는 출근 퇴근시간, 주말엔 오후에 대여를 많이하고있단걸 볼수있다.

figure, (ax1,ax2) = plt.subplots(nrows=2, ncols=1)
figure.set_size_inches(18,8)

sns.pointplot(data=train, x="datatime-hour",y="count",ax=ax1)
sns.pointplot(data=train, x="datatime-hour",y="count",hue="datatime-dayofweek",ax=ax2)

# %%
def concatenate_year_month(datetime):
    return "{0}{1}".format(datetime.year,datetime.month)
##datetime의 year를 0에 month를 1에 넣어라

train["datetime-year_month"] = train["datetime"].apply(concatenate_year_month)
test["datetime-year_month"] = test["datetime"].apply(concatenate_year_month)
train[["datetime","datetime-year_month"]].head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-33482aff4e62> in <module>()
#       4
#       5 train["datetime-year_month"] = train["datetime"].apply(concatenate_year_month)
# ----> 6 test["datetime-year_month"] = test["datetime"].apply(concatenate_year_month)
#       7 train[["datetime","datetime-year_month"]].head()
#
# NameError: name 'test' is not defined

# %%
test[["datetime","datetime-year_month"]].head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-64ed47a03f9a> in <module>()
# ----> 1 test[["datetime","datetime-year_month"]].head()
#
# NameError: name 'test' is not defined

# %%
figure, (ax1, ax2) = plt.subplots(nrows = 2, ncols = 1)
figure.set_size_inches(18,8)

sns.barplot(data = train, x = "datatime-year", y = "count", ax = ax1)
sns.barplot(data = train, x = "datatime-month", y = "count", ax = ax2)

figure, ax3 = plt.subplots(nrows = 1, ncols = 1)
figure.set_size_inches(18,8)

sns.barplot(data = train, x = "datetime-year_month", y = "count", ax = ax3)

# %%
#reload dataset

# %%
train=pd.read_csv("biketrain.csv",parse_dates=["datetime"])
train.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
test=pd.read_csv("bikete.csv",parse_dates=["datetime"])
test.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
def concatenate_year_month(datetime):
    return "{0}{1}".format(datetime.year,datetime.month)
##datetime의 이어를 0에 먼스를 1에 넣어라

train["datetime-year_month"] = train["datetime"].apply(concatenate_year_month)
test["datetime-year_month"] = test["datetime"].apply(concatenate_year_month)
train[["datetime","datetime-year_month"]].head()
test[["datetime","datetime-year_month"]].head()
# Out:
#              datetime datetime-year_month
# 0 2011-01-01 00:00:00               20111
# 1 2011-01-01 01:00:00               20111
# 2 2011-01-01 02:00:00               20111
# 3 2011-01-01 03:00:00               20111
# 4 2011-01-01 04:00:00               20111

# %%
test["datetime-year"]=test["datetime"].dt.year
test["datetime-month"]=test["datetime"].dt.month
test["datetime-day"]=test["datetime"].dt.day
test["datetime-hour"]=test["datetime"].dt.hour
test["datetime-minute"]=test["datetime"].dt.minute
test["datetime-second"]=test["datetime"].dt.second
test["datetime-dayofweek"]=test["datetime"].dt.dayofweek

# %%
train["datetime-year"]=train["datetime"].dt.year
train["datetime-month"]=train["datetime"].dt.month
train["datetime-day"]=train["datetime"].dt.day
train["datetime-hour"]=train["datetime"].dt.hour
train["datetime-minute"]=train["datetime"].dt.minute
train["datetime-second"]=train["datetime"].dt.second
train["datetime-dayofweek"]=train["datetime"].dt.dayofweek

# %%
train.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count datetime-year_month  \
# 0        81        0.0       3          13     16               20111
# 1        80        0.0       8          32     40               20111
# 2        80        0.0       5          27     32               20111
# 3        75        0.0       3          10     13               20111
# 4        75        0.0       0           1      1               20111
#
#    datetime-year  datetime-month  datetime-day  datetime-hour  \
# ...

# %%
#온도를합해보자

train["Temperature"] = train["temp"]+train["atemp"]

test["Temperature"] = test["temp"]+test["atemp"]

# %% [markdown]
# ##### Train

# %%
feature_names=["temp","datetime-dayofweek","holiday","workingday","season","datetime-year_month","datetime-hour",
               "atemp","humidity","windspeed","Temperature"]
feature_names
# Out:
# ['temp',
#  'datetime-dayofweek',
#  'holiday',
#  'workingday',
#  'season',
#  'datetime-year_month',
#  'datetime-hour',
#  'atemp',
#  'humidity',
#  'windspeed',
#  'Temperature']

# %%
X_train = train[feature_names]
X_train.head()
X_test = test[feature_names]
X_test.head()
# Out:
#    temp  datetime-dayofweek  holiday  workingday  season datetime-year_month  \
# 0  9.84                   5        0           0       1               20111
# 1  9.02                   5        0           0       1               20111
# 2  9.02                   5        0           0       1               20111
# 3  9.84                   5        0           0       1               20111
# 4  9.84                   5        0           0       1               20111
#
#    datetime-hour   atemp  humidity  windspeed  Temperature
# 0              0  14.395        81        0.0       24.235
# 1              1  13.635        80        0.0       22.655
# 2              2  13.635        80        0.0       22.655
# 3              3  14.395        75        0.0       24.235
# 4              4  14.395        75        0.0       24.235

# %%
label_name="count"
y_train=train[label_name]
y_train.head()
# Out:
# 0    16
# 1    40
# 2    32
# 3    13
# 4     1
# Name: count, dtype: int64

# %%
#1.일반적인 의사결정트리

# from sklearn.tree import DecisionTreeRegressor
# model = DecisionTreeRegressor(random_state=27)
# model
# model.fit(X_train, y_train)

#2.랜덤포레스트(여러개의 의사결정트리를생성 학습과정에서 가장 정확도가 높은 의사결정을 채용하는 알고리즘)성능더좋넹
#n_estimator = 몇번..?몇개,,? 하여튼 횟수임. 많을수록 더 좋아짐 ,실업무에선 3~5만정도로 한다고함 오래걸림
#n_jobs=-1 cpu사용갯수, -1은 모든 cpu를사용해라 기본은 1임

from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=100,random_state=27, n_jobs=-1,max_depth=9)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=9,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=100, n_jobs=-1, oob_score=False, random_state=27,
#            verbose=0, warm_start=False)

# %%
predictions=model.predict(X_test)
predictions
# Out:
# array([  25.28618387,   29.13003056,   25.1509862 , ...,  179.66055165,
#         140.41249859,   94.65706895])

# %% [markdown]
# 중요하니?

# %%
model.feature_importances_
list(zip(feature_names,model.feature_importances_))
# Out:
# [('temp', 0.03655239007180934),
#  ('datetime-dayofweek', 0.047451360356963915),
#  ('holiday', 0.0019195340232948414),
#  ('workingday', 0.051733677309283861),
#  ('season', 0.0018074305397926072),
#  ('datetime-year_month', 0.14850052992570553),
#  ('datetime-hour', 0.63900193640540159),
#  ('atemp', 0.036497703896375779),
#  ('humidity', 0.019499474648913787),
#  ('windspeed', 0.0011394888124041582),
#  ('Temperature', 0.015896474010054604)]

# %% [markdown]
# ##### score

# %%
from sklearn.metrics import make_scorer
def rmsle(predict,actual):
    predict = np.array(predict)
    actual= np.array(actual)
    log_predict = np.log(predict+1)
    log_actual = np.log(actual+1)
    
    difference = log_predict - log_actual
    square_difference = difference ** 2
    mean_square_difference = square_difference.mean()
    
    score = np.sqrt(mean_square_difference)
    
    return score

print(rmsle([1,2,3],[1,2,3]))

rmsle_score = make_scorer(rmsle)
rmsle_score
# Out:
# 0.0
# make_scorer(rmsle)

# %%
from sklearn.cross_validation import cross_val_score
score=cross_val_score(model, X_train, y_train, cv=20, scoring = rmsle_score).mean()
print(score)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# 0.428686319524

# %% [markdown]
# ##### sample

# %%
test.index
# Out:
# RangeIndex(start=0, stop=10886, step=1)

# %%
submission = pd.read_csv("bikesampleSubmission.csv")

submission["count"] = predictions
submission.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-210-752e33030623> in <module>()
#       1 submission = pd.read_csv("bikesampleSubmission.csv")
#       2
# ----> 3 submission["count"] = predictions
#       4 submission.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2427         else:
#    2428             # set column
# -> 2429             self._set_item(key, value)
#    2430
#    2431     def _setitem_slice(self, key, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2493
#    2494         self._ensure_valid_index(value)
# -> 2495         value = self._sanitize_column(key, value)
#    2496         NDFrame._set_item(self, key, value)
#    2497
#
# ...

# %%
filename="bikesubmissionReal.csv"
submission.to_csv(filename,index=False)
